# %%
# from https://github.com/rom1504/img2dataset/blob/main/dataset_examples/cc12m.md

# !NO_ALBUMENTATIONS_UPDATE=1 img2dataset --url_list cc3m.tsv --input_format "tsv"\
         --url_col "url" --caption_col "caption" --output_format webdataset\
           --output_folder cc3m --processes_count 16 --thread_count 64 --image_size 256
# Out:
# Starting the downloading of this file
# Sharding file number 1 of 1 called /workspace/cc3m.tsv
# File sharded in 332 shards
# ...
# worker  - success: 0.670 - failed to download: 0.305 - failed to resize: 0.025 - images per sec: 60 - count: 10000
# total   - success: 0.670 - failed to download: 0.305 - failed to resize: 0.025 - images per sec: 60 - count: 10000
# worker  - success: 0.687 - failed to download: 0.293 - failed to resize: 0.020 - images per sec: 54 - count: 10000
# total   - success: 0.678 - failed to download: 0.299 - failed to resize: 0.022 - images per sec: 109 - count: 20000
# worker  - success: 0.676 - failed to download: 0.298 - failed to resize: 0.026 - images per sec: 53 - count: 10000
# total   - success: 0.678 - failed to download: 0.299 - failed to resize: 0.023 - images per sec: 159 - count: 30000
# worker  - success: 0.678 - failed to download: 0.301 - failed to resize: 0.021 - images per sec: 51 - count: 10000
# ...

# %%
# !sed -i '1d' cc12m.tsv
# !head cc12m.tsv
# Out:
# a very typical bus station	http://lh6.ggpht.com/-IvRtNLNcG8o/TpFyrudaT6I/AAAAAAAAM6o/_11MuAAKalQ/IMG_3422.JPG?imgmax=800
# sierra looked stunning in this top and this skirt while performing with person at their former university	http://78.media.tumblr.com/3b133294bdc7c7784b781b45eb9af7be/tumblr_nbirmjpEme1tkk0fco1_500.jpg
# young confused girl standing in front of a wardrobe	https://media.gettyimages.com/photos/young-confused-girl-standing-in-front-of-a-wardrobe-picture-id511063329?s=612x612
# interior design of modern living room with fireplace in a new house	https://thumb1.shutterstock.com/display_pic_with_logo/152074/125938838/stock-photo-interior-design-of-modern-living-room-with-fireplace-in-a-new-house-125938838.jpg
# cybernetic scene isolated on white background .	https://thumb1.shutterstock.com/display_pic_with_logo/324673/177023534/stock-photo-cybernetic-scene-isolated-on-white-background-sci-fi-robot-arm-made-of-compound-metallic-as-a-177023534.jpg
# ...
